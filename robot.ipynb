# %% [markdown]
# <a href="https://colab.research.google.com/github/wfq1971/discord-bot/blob/main/robot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install discord
# !pip install colorama
# !pip3 install python-dotenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 11.7 MB/s eta 0:00:00
# ...

# %%
# !python /content/drive/MyDrive/main.py
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/main.py", line 958, in <module>
#     run()
#   File "/content/drive/MyDrive/main.py", line 738, in run
#     TOKEN = userdata.get('DISCORD_TOKEN')
#   File "/usr/local/lib/python3.10/dist-packages/google/colab/userdata.py", line 49, in get
#     resp = _message.blocking_request(
#   File "/usr/local/lib/python3.10/dist-packages/google/colab/_message.py", line 173, in blocking_request
#     request_id = send_request(
#   File "/usr/local/lib/python3.10/dist-packages/google/colab/_message.py", line 117, in send_request
#     instance = ipython.get_kernelapp()
#   File "/usr/local/lib/python3.10/dist-packages/google/colab/_ipython.py", line 28, in get_kernelapp
#     return get_ipython().kernel.parent
# AttributeError: 'NoneType' object has no attribute 'kernel'

# %%
# !pip install nest_asyncio

# %%
import json
import os
import platform
from datetime import datetime
import discord
import pandas as pd
import requests
import time
import sqlite3
import re

from colorama import Fore
from discord import app_commands
from discord.ext import commands
from dotenv import load_dotenv
import csv
from prettytable import PrettyTable
from google.colab import userdata
import asyncio
import nest_asyncio
nest_asyncio.apply()

#df=pd.read_csv('SimCompanyDatabase.csv')
#dA=pd.read_csv('SimCompanyDatabase A.csv')
#dB=pd.read_csv('SimCompanyDatabase B.csv')
#dC=pd.read_csv('SimCompanyDatabase C.csv')
#dD=pd.read_csv('SimCompanyDatabase D.csv')
#dE=pd.read_csv('SimCompanyDatabase E.csv')
#dF=pd.read_csv('SimCompanyDatabase F.csv')
#dG=pd.read_csv('SimCompanyDatabase G.csv')
#dH=pd.read_csv('SimCompanyDatabase H.csv')
#dI=pd.read_csv('SimCompanyDatabase I.csv')
#dJ=pd.read_csv('SimCompanyDatabase J.csv')
dA='/content/drive/MyDrive/SimCompanyDatabase A.csv'
dB='/content/drive/MyDrive/SimCompanyDatabase B.csv'
dC='/content/drive/MyDrive/SimCompanyDatabase C.csv'
dD='/content/drive/MyDrive/SimCompanyDatabase D.csv'
dE='/content/drive/MyDrive/SimCompanyDatabase E.csv'
dF='/content/drive/MyDrive/SimCompanyDatabase F.csv'
dG='/content/drive/MyDrive/SimCompanyDatabase G.csv'
dH='/content/drive/MyDrive/SimCompanyDatabase H.csv'
dI='/content/drive/MyDrive/SimCompanyDatabase I.csv'
dJ='/content/drive/MyDrive/SimCompanyDatabase J.csv'
df='/content/drive/MyDrive/SimCompanyDatabase.csv'
zhixingcishu=1
def formsa(csvs):
    with open(csvs, newline='') as csvfile:
        csvreader = csv.reader(csvfile)
        data = list(csvreader)

   #創建表格對象
    table = PrettyTable()
    table.field_names = data[0]
    for field in table.field_names:
        table.align[field] = 'c'

   #將數據添加到表格中
    for row in data[1:]:
        formatted_row = [str(cell).center(10) for cell in row]
        table.add_row(formatted_row)
    return table
   # 发送表格内容

def chatgpt(abc):
  url = "https://genie-production-yfvxbm4e6q-uc.a.run.app/chats/j3jsGI70nhqCF1knEVQY/completions/ka3gx0JnibeZgbvLTMAs"

  payload = {
    "messages": [
        {
            "fromUser": False,
            "media": None,
            "content": "You are an assistant named Genie developed by AppNation. Always answer as helpfully as possible. Current date is July 3, 2024.",
            "id": "temp-GP79kKC0Ldjs0OP3TB8L",
            "type": "system",
            "createdAt": 1719978300781
        },
        {
            "chatId": "j3jsGI70nhqCF1knEVQY",
            #"content": "聊一聊編寫python程序的好處",
            "content": abc,
            "id": "temp-McurrXrmbmDs3Hxz5kFr",
            "media": None,
            "type": "message",
            "fromUser": True,
            "createdAt": 1719978300795
        }
    ],
    "regeneratedMessageId": None,
    "model": "OPEN_AI_CHATGPT_4_0_CHAT_MODEL",
    "isForImageGeneration": False,
    "user": "suGy7tXKbcabWjWqW8Gh6k9f07W2",
    "parameters": {
        "maxTokens": 1000,
        "stop": [],
        "temperature": 0.7,
        "topP": 1.0,
        "frequencyPenalty": 0,
        "presencePenalty": 0,
        "n": 1
    }
  }

  headers = {
    "Content-Type": "application/json",
    "Authorization": "Bearer eyJhbGciOiJSUzI1NiIsImtpZCI6IjZjYzNmY2I2NDAzMjc2MGVlYjljMjZmNzdkNDA3YTY5NGM1MmIwZTMiLCJ0eXAiOiJKV1QifQ.....erTpxsxYhkne9pB-EEB-b4l6LS9VdIqhfNGSUAb2vptfnlapxlBc4uLJGQTpcwhIU7Y1z8gVJUfKnL0IBCSSyf-fTxREoUb-EcB7HEj7mHjL6jFNz3DaXk1MJmSMzsiyMZFPNwTOcNd-P8hjJoB4kzNuEGmpn8zhPtfgAc1Xbs10Yc8iefJ1F_3YULVHoCA_r1DRYx_I-TUhPOr8eL_uQBWH2U85m9K52oBPJGkLKJR5XC5-qZyxqIWn9htD079Li4kR8Xb5dBcKPPjE5nvDD-TFZ5qM0UGp0MZzPU5Zm6iFITu303QW5xn8p-7N9ZBLKGKqNFkCDoJXlDzCeakLJA"
  }

  response = requests.post(url, json=payload, headers=headers)
  data=response.text
  single_line_text = data.replace('\n', '')
  if(data=="Failed5"):
    single_line_texts2="叫服主更新令牌啦！"
    return single_line_texts2
  matches = re.findall(r'data: \{\"content\":\"(.*?)\"\}', str(single_line_text))
  kk=''# 打印匹配结果
  for match in matches:
    kk+=str(match)
  single_line_texts = kk.replace('\n', '')
  single_line_texts2 = single_line_texts.replace('\\n', '')
  return single_line_texts2

def extract_content(jsons):
    data = json.loads(jsons)
    contents = []
    for item in data:
        if "\"content\"" in item:
            contents.append(item["content"])
            return data


class functionmenu(discord.ui.View):
    answer1=None
    def __init__(self, *, ids=None):  # Add custom_data argument here
        super().__init__()
        self.custom_data = ids
    @discord.ui.select(
        placeholder="請輸入你需要使用的功能！",
        options=[
        discord.SelectOption(label="查詢交易所價格", value="EPrice"),
        discord.SelectOption(label="查詢商店價格", value="Price"),
        discord.SelectOption(label="計算製造利潤", value="profit"),
        discord.SelectOption(label="查詢配方菜單", value="h2mi"),
        ]
    )

    async def selects(self, i:discord.Interaction,select_item : discord.ui.Select):
        responsena=requests.get(f'https://www.simcompanies.com/api/v4/zh/0/encyclopedia/resources/1/{self.custom_data}/')
        messagena = json.dumps(responsena.json(), indent=4, ensure_ascii=False)#解碼json數據
        if(select_item.values == ['profit']):
            await i.response.send_modal(ceshi(custom_data=self.custom_data))
        elif(select_item.values == ['Price']):
            txt=json.loads(messagena)#加載json數據到txt
            gone1=txt.get('averageRetailPrice')
            name=txt.get('name')
            soldAt=txt.get('soldAt')
            if(soldAt == 'G'):
              soldAt='生鮮超市'
            elif(soldAt == 'd'):
              soldAt='五金商店'
            elif(soldAt == 'H'):
              soldAt='時裝商店'
            elif(soldAt == 'A'):
              soldAt='加油站'
            elif(soldAt == 'C'):
              soldAt='電子產品商店'
            elif(soldAt == '2'):
              soldAt='車行'
            if(gone1 != None):
                RETAILPRICE=round(gone1,2)#限制小數位
                await  i.response.send_message(content=f"{name}的{soldAt}行情價是: {RETAILPRICE}",ephemeral=True)#,\n{name}不計算原料的生產成本的部分: {chengben2}
            else:
                await  i.response.send_message(content=f"{name}不可售賣",ephemeral=True)#,\n{name}不計算原料的生產成本的部分: {chengben2}
                pass

        elif(select_item.values == ['EPrice']):
            response=requests.get(f'https://www.simcompanies.com/api/v3/market/0/{self.custom_data}/')#從api中拉入價格數據
            message = json.dumps(response.json(), indent=4, ensure_ascii=False)#解碼json數據
            txtna=json.loads(messagena)#加載json數據到txt
            name=txtna.get('name')
            txt=json.loads(message)#加載json數據到txt
            gone1=txt[0].get('price')#查找價格標簽並輸入變量gone1
            await i.response.send_message(content=f"{name}的最低價是: {gone1}",ephemeral=True)
        elif(select_item.values == ['h2mi']):
            resor2=None;resor3=None;resor4=None;resor5=None;rprice02=None;rprice03=None;rprice04=None;rprice05=None
            if(self.custom_data == 1 or self.custom_data == 145 or self.custom_data == 113 or self.custom_data == 58 or self.custom_data == 59 or self.custom_data == 100):
              await i.response.send_message(content=f"這個物資生產不需要材料！",ephemeral=True)
            elif(self.custom_data >= 29 and self.custom_data<=35):
              await i.response.send_message(content=f"這個物資不需要材料！",ephemeral=True)
              return False
            else:
              pass

            txt=json.loads(messagena)#加載json數據到txt
            print(txt)
            name=txt.get('name')
            resor1=txt.get('producedFrom')[0].get('resource').get('name')
            print(resor1)
            resor1price=txt.get('producedFrom')[0].get('resource').get('db_letter')
            response1=requests.get(f'https://www.simcompanies.com/api/v3/market/0/{resor1price}/')#從api中拉入價格數據
            message01 = json.dumps(response1.json(), indent=4, ensure_ascii=False)#解碼json數據
            txt01=json.loads(message01)#加載json數據到txt
            rprice01=txt01[0].get('price')#查找價格標簽並輸入變量gone1
            try:
                resor2=txt.get('producedFrom')[1].get('resource').get('name')
                resor2price=txt.get('producedFrom')[1].get('resource').get('db_letter')
                response2=requests.get(f'https://www.simcompanies.com/api/v3/market/0/{resor2price}/')#從api中拉入價格數據
                message02 = json.dumps(response2.json(), indent=4, ensure_ascii=False)#解碼json數據
                txt02=json.loads(message02)#加載json數據到txt
                rprice02=txt02[0].get('price')#查找價格標簽並輸入變量gone1
            except(IndexError, KeyError):
                pass
            except Exception:
                pass
            try:
                resor3=txt.get('producedFrom')[2].get('resource').get('name')
                resor3price=txt.get('producedFrom')[2].get('resource').get('db_letter')
                response3=requests.get(f'https://www.simcompanies.com/api/v3/market/0/{resor3price}/')#從api中拉入價格數據
                message03 = json.dumps(response3.json(), indent=4, ensure_ascii=False)#解碼json數據
                txt03=json.loads(message03)#加載json數據到txt
                rprice03=txt03[0].get('price')#查找價格標簽並輸入變量gone1
            except(IndexError, KeyError):
                pass
            except Exception:
                pass
            try:
                resor4=txt.get('producedFrom')[3].get('resource').get('name')
                resor4price=txt.get('producedFrom')[3].get('resource').get('db_letter')
                response4=requests.get(f'https://www.simcompanies.com/api/v3/market/0/{resor4price}/')#從api中拉入價格數據
                message04 = json.dumps(response4.json(), indent=4, ensure_ascii=False)#解碼json數據
                txt04=json.loads(message04)#加載json數據到txt
                rprice04=txt04[0].get('price')#查找價格標簽並輸入變量gone1
            except(IndexError, KeyError):
                pass
            except Exception:
                pass

            try:
                resor5=txt.get('producedFrom')[4].get('resource').get('name')
                resor5price=txt.get('producedFrom')[4].get('resource').get('db_letter')
                response5=requests.get(f'https://www.simcompanies.com/api/v3/market/0/{resor5price}/')#從api中拉入價格數據
                message05 = json.dumps(response5.json(), indent=4, ensure_ascii=False)#解碼json數據
                txt05=json.loads(message05)#加載json數據到txt
                rprice05=txt05[0].get('price')#查找價格標簽並輸入變量gone1
            except(IndexError, KeyError):
                pass
            except Exception:
                pass
            # 所有其他異常的處理方式
            if(resor2 == None):
                await i.response.send_message(content=f"{name}需要的材料是: {resor1}，它在交易所的價格是：{rprice01}",ephemeral=True)
            elif(resor3 == None):
                await i.response.send_message(content=f"{name}需要的第一種材料是: {resor1}，它在交易所的價格是：{rprice01}，第二種材料是{resor2}，它在交易所的價格是：{rprice02}",ephemeral=True)
            elif(resor4 == None):
                await i.response.send_message(content=f"{name}需要的第一種材料是: {resor1}，它在交易所的價格是：{rprice01}，第二種材料是{resor2}，它在交易所的價格是：{rprice02},第三種材料是{resor3}，它在交易所的價格是：{rprice03}",ephemeral=True)
            elif(resor5 == None):
                await i.response.send_message(content=f"{name}需要的第一種材料是: {resor1}，它在交易所的價格是：{rprice01}，第二種材料是{resor2}，它在交易所的價格是：{rprice02},第三種材料是{resor3}，它在交易所的價格是：{rprice03},第四種材料是{resor4}，它在交易所的價格是：{rprice04}",ephemeral=True)
            else:
                await i.response.send_message(content=f"{name}需要的第一種材料是: {resor1}，它在交易所的價格是：{rprice01}，第二種材料是{resor2}，它在交易所的價格是：{rprice02},第三種材料是{resor3}，它在交易所的價格是：{rprice03},第四種材料是{resor4}，它在交易所的價格是：{rprice04}，第五種材料是{resor5}，它在交易所的價格是：{rprice05}",ephemeral=True)






class ceshi(discord.ui.Modal,title="請輸入以下各計算值"):#這是彈出框的類型
    glfp=discord.ui.TextInput(
        label="管理費趴數",
    )
    jzdj=discord.ui.TextInput(
        label="建築等級",
    )
    scsjc=discord.ui.TextInput(
        label="生產數目加成",
    )
    badboy=None
    def __init__(self, *, custom_data=None):  # Add custom_data argument here
        super().__init__()
        self.custom_data = custom_data
    async def on_submit(self, i:discord.Interaction):
        glfp=float(self.glfp.value)
        jzdj=float(self.jzdj.value)
        scsjc=float(self.scsjc.value)

        response=requests.get(f'https://www.simcompanies.com/api/v4/zh/0/encyclopedia/resources/1/{self.custom_data}/')#從api中拉入價格數據
        message = json.dumps(response.json(), indent=4, ensure_ascii=False)#解碼json數據
        txt=json.loads(message)#加載json數據到txt
        name=txt.get('name')
        producedAnHour=txt.get('producedAnHour')#獲取生產建築的產量（1級別）
        producedAnHour=float(producedAnHour)
        ProducebaseSalary=txt.get('baseSalary')#獲取生產建築的薪資（1級別）
        ProducebaseSalary=float(ProducebaseSalary)
        guanlifei=glfp/100#前面那個100需要做一個輸入的界面（管理費的趴數）
        jianzhulevel=jzdj#這是建築等級⁷
        shengchanjiasu=scsjc/100#生產加速的值（2就是2%）之後需要客戶修改的地方
        chengben=((ProducebaseSalary/(1/(1-shengchanjiasu)))/producedAnHour*(1+guanlifei))*jianzhulevel #計算生產成本公式
        chengben2=round(chengben,2)
        await  i.response.send_message(content=f"{name}不計算原料的生產成本的部分: {chengben2}",ephemeral=True)#,\n
class AgricultureCol(discord.ui.View):
        answer1=None
        @discord.ui.select(
            placeholder="請選擇物資！",
            options=[
            discord.SelectOption(label="種子", value="seeds"),
            discord.SelectOption(label="蘋果", value="apple"),
            discord.SelectOption(label="橘子", value="orange"),
            discord.SelectOption(label="葡萄", value="grape"),
            discord.SelectOption(label="穀物", value="wales"),
            discord.SelectOption(label="牛", value="cow"),
            discord.SelectOption(label="豬", value="pig"),
            discord.SelectOption(label="咖啡豆", value="coffeebean"),
            discord.SelectOption(label="蔬菜", value="vegetable"),
            discord.SelectOption(label="動物飼料", value="fooder"),
            discord.SelectOption(label="棉花", value="cotton"),
            discord.SelectOption(label="甘蔗", value="sugarcane"),
            discord.SelectOption(label="可可", value="cocoa"),
            ]
        )
        async def selects(self, i:discord.Interaction,select_item : discord.ui.Select):
            if(select_item.values == ['seeds']):
                id=66
                view = functionmenu(ids=id)
                await i.response.send_message(view=view,ephemeral=True)
                await view.wait()
            elif(select_item.values == ['apple']):
                id=3
                view = functionmenu(ids=id)
                await i.response.send_message(view=view,ephemeral=True)
                await view.wait()
            elif(select_item.values == ['orange']):
                id=4
                view = functionmenu(ids=id)
                await i.response.send_message(view=view,ephemeral=True)
                await view.wait()
            elif(select_item.values == ['grape']):
                id=5
                view = functionmenu(ids=id)
                await i.response.send_message(view=view,ephemeral=True)
                await view.wait()
            elif(select_item.values == ['wales']):
                id=6
                view = functionmenu(ids=id)
                await i.response.send_message(view=view,ephemeral=True)
                await view.wait()
            elif(select_item.values == ['cow']):
                id=115
                view = functionmenu(ids=id)
                await i.response.send_message(view=view,ephemeral=True)
                await view.wait()
            elif(select_item.values == ['pig']):
                id=116
                view = functionmenu(ids=id)
                await i.response.send_message(view=view,ephemeral=True)
                await view.wait()
            elif(select_item.values == ['coffeebean']):
                id=118
                view = functionmenu(ids=id)
                await i.response.send_message(view=view,ephemeral=True)
                await view.wait()
            elif(select_item.values == ['vegetable']):
                id=120
                view = functionmenu(ids=id)
                await i.response.send_message(view=view,ephemeral=True)
                await view.wait()
            elif(select_item.values == ['fooder']):
                id=139
                view = functionmenu(ids=id)
                await i.response.send_message(view=view,ephemeral=True)
                await view.wait()
            elif(select_item.values == ['cotton']):
                id=40
                view = functionmenu(ids=id)
                await i.response.send_message(view=view,ephemeral=True)
                await view.wait()
            elif(select_item.values == ['sugarcane']):
                id=72
                view = functionmenu(ids=id)
                await i.response.send_message(view=view,ephemeral=True)
                await view.wait()
            elif(select_item.values == ['cocoa']):
                id=136
                view = functionmenu(ids=id)
                await i.response.send_message(view=view,ephemeral=True)
                await view.wait()

class FoodCol(discord.ui.View):
    answer1=None
    @discord.ui.select(
        placeholder="請選擇物資種類！",
        options=[
        discord.SelectOption(label="麵食", value="pow"),
        discord.SelectOption(label="家畜類製品", value="meat"),
        discord.SelectOption(label="零食和飲料", value="drink"),
        ]
    )
    async def selects(self, i:discord.Interaction,select_item : discord.ui.Select):
        if(select_item.values == ['pow']):
            view = mianshi()
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
        elif(select_item.values == ['meat']):
            view = chulei()
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
        elif(select_item.values == ['drink']):
            view = snanddrk()
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()


class mianshi(discord.ui.View):
    answer1=None
    @discord.ui.select(
        placeholder="請選擇物資！",
        options=[
        discord.SelectOption(label="麵糰", value="dom"),
        discord.SelectOption(label="麵粉", value="pod"),
        discord.SelectOption(label="麵包", value="bread"),
        discord.SelectOption(label="蘋果派", value="applepie"),
        discord.SelectOption(label="披薩", value="piza"),
        discord.SelectOption(label="麵條", value="nod"),
        discord.SelectOption(label="漢堡", value="ham"),
        discord.SelectOption(label="千層麵", value="spg"),
        ]
    )
    async def selects(self, i:discord.Interaction,select_item : discord.ui.Select):
        if(select_item.values == ['dom']):
          id=137
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
        elif(select_item.values == ['pod']):
          id=133
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
        elif(select_item.values == ['bread']):
          id=121
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
        elif(select_item.values == ['applepie']):
          id=123
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
        elif(select_item.values == ['piza']):
          id=127
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
        elif(select_item.values == ['ham']):
          id=129
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
        elif(select_item.values == ['spg']):
          id=128
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()




class chulei(discord.ui.View):
    answer1=None
    name=None
    gone1=None
    @discord.ui.select(
        placeholder="請選擇物資！",
        options=[
            discord.SelectOption(label="牛排", value="steak"),
            discord.SelectOption(label="香腸", value="sau"),
            discord.SelectOption(label="鷄蛋", value="egg"),
            discord.SelectOption(label="牛奶", value="milk"),
            discord.SelectOption(label="奶油", value="cream"),
            discord.SelectOption(label="芝士", value="cheese"),
            discord.SelectOption(label="肉丸", value="meatb"),
        ]
    )
    async def selects(self, i:discord.Interaction,select_item : discord.ui.Select):
        if(select_item.values == ['cheese']):
            id=122
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
        elif(select_item.values == ['steak']):
            id=7
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
        elif(select_item.values == ['sau']):
            id=8
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
        elif(select_item.values == ['egg']):
            id=9
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
        elif(select_item.values == ['milk']):
            id=117
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
        elif(select_item.values == ['cream']):
            id=134
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
        elif(select_item.values == ['meatb']):
            id=131
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()



class snanddrk(discord.ui.View):
    answer1=None
    @discord.ui.select(
        placeholder="請選擇物資！",
        options=[
            discord.SelectOption(label="咖啡粉", value="coffeep"),
            discord.SelectOption(label="橙汁", value="orgj"),
            discord.SelectOption(label="蘋果汁", value="appj"),
            discord.SelectOption(label="薑汁汽水", value="genj"),
            discord.SelectOption(label="巧克力", value="chocolate"),
            discord.SelectOption(label="糖", value="sugar"),
            discord.SelectOption(label="醬汁", value="sause"),
            discord.SelectOption(label="混合果汁", value="mixj"),
            discord.SelectOption(label="植物油", value="eatoil"),
            discord.SelectOption(label="沙拉", value="salad"),
            discord.SelectOption(label="咖喱角", value="curry"),
        ]
    )
    async def selects(self, i:discord.Interaction,select_item : discord.ui.Select):
        if(select_item.values == ['coffeep']):
          id=119
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
        elif(select_item.values == ['orgj']):
          id=124
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
          id=125
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
        elif(select_item.values == ['genj']):
          id=126
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
        elif(select_item.values == ['chocolate']):
          id=140
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
        elif(select_item.values == ['sugar']):
          id=135
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
          id=138
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
        elif(select_item.values == ['mixj']):
          id=132
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
        elif(select_item.values == ['eatoil']):
          id=141
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
        elif(select_item.values == ['salad']):
          id=142
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
        elif(select_item.values == ['curry']):
          id=143
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()


class ConstructionCol(discord.ui.View):
    answer1=None
    @discord.ui.select(
        placeholder="請選擇物資！",
        options=[
            discord.SelectOption(label="鋼筋混凝土", value="concrete"),
            discord.SelectOption(label="磚塊", value="bricks"),
            discord.SelectOption(label="木板", value="planks"),
            discord.SelectOption(label="建築預購件", value="cu"),
            discord.SelectOption(label="黏土", value="CLAY"),
            discord.SelectOption(label="木材", value="WOOD"),
            discord.SelectOption(label="水泥", value="CEMENT"),
            discord.SelectOption(label="石灰石", value="LIMESTONE"),
            discord.SelectOption(label="鋼筋", value="STEEL"),
            discord.SelectOption(label="窗戶", value="WINDOW"),
            discord.SelectOption(label="工具", value="TOOLS"),
        ]
    )
    async def selects(self, i:discord.Interaction,select_item : discord.ui.Select):
        if(select_item.values == ['concrete']):
          id=101
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
        elif(select_item.values == ['bricks']):
          id=102
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
        elif(select_item.values == ['planks']):
          id=108
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
        elif(select_item.values == ['cu']):
          id=111
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
        elif(select_item.values == ['CLAY']):
          id=104
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
        elif(select_item.values == ['WOOD']):
          id=106
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
        elif(select_item.values == ['CEMENT']):
          id=103
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
        elif(select_item.values == ['LIMESTONE']):
          id=105
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
        elif(select_item.values == ['STEEL']):
          id=107
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
        elif(select_item.values == ['WINDOW']):
          id=109
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
        elif(select_item.values == ['TOOLS']):
          id=110
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()


class FashionCol(discord.ui.View):#view是選擇的那個框
    answer1=None#這是可以傳到主程序的變量（變數）
    @discord.ui.select(
        placeholder="請選擇物資！",#這是下拉框的提示内容
        options=[
            discord.SelectOption(label="棉布", value="FABRIC"),#這是選項中的一個選項
            discord.SelectOption(label="皮革", value="LEATHER"),
            discord.SelectOption(label="内衣", value="UNDERWARE"),
            discord.SelectOption(label="手套", value="GLOVES"),
            discord.SelectOption(label="裙子", value="DRESS"),
            discord.SelectOption(label="高跟鞋", value="Heel"),
            discord.SelectOption(label="手袋", value="HANDBAGS"),
            discord.SelectOption(label="運動鞋", value="SNEAKERS"),
            discord.SelectOption(label="名牌手錶", value="WATCH"),
            discord.SelectOption(label="項鏈", value="NECKLACE"),
        ]
    )
    async def selects(self, i:discord.Interaction,select_item : discord.ui.Select):#下拉選擇完成之後的邏輯
        if(select_item.values == ['FABRIC']):
          id=41
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
        elif(select_item.values == ['LEATHER']):
          id=46
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
        elif(select_item.values == ['UNDERWARE']):
          id=60
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
          await view.wait()
        elif(select_item.values == ['GLOVES']):
          id=61
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['DRESS']):
          id=62
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['Heel']):
          id=63
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['HANDBAGS']):
          id=64
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['SNEAKERS']):
          id=65
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['WATCH']):
          id=70
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['NECKLACE']):
          id=71
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)



class EnergyCol(discord.ui.View):#view是選擇的那個框
    answer1=None#這是可以傳到主程序的變量（變數）
    @discord.ui.select(
        placeholder="請選擇物資！",#這是下拉框的提示内容
        options=[
            discord.SelectOption(label="電力", value="POWER"),#這是選項中的一個選項
            discord.SelectOption(label="原油", value="OIL"),
            discord.SelectOption(label="汽油", value="PETROL"),
            discord.SelectOption(label="柴油", value="DISEL"),
            discord.SelectOption(label="乙醇", value="ETHANOL"),
            discord.SelectOption(label="甲烷", value="METHANE"),
            discord.SelectOption(label="火箭燃料", value="ROCKETF"),

        ]
    )
    async def selects(self, i:discord.Interaction,select_item : discord.ui.Select):#下拉選擇完成之後的邏輯
        if(select_item.values == ['POWER']):
          id=1
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['OIL']):
          id=10
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['PETROL']):
          id=11
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['DISEL']):
          id=12
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['ETHANOL']):
          id=73
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['METHANE']):
          id=74
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['ROCKETF']):
          id=83
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)

class ElectronicsCol(discord.ui.View):#view是選擇的那個框
    answer1=None#這是可以傳到主程序的變量（變數）
    @discord.ui.select(
        placeholder="請選擇物資！",#這是下拉框的提示内容
        options=[
            discord.SelectOption(label="處理器", value="PROCESSORS"),#這是選項中的一個選項
            discord.SelectOption(label="電子原件", value="Electronic"),
            discord.SelectOption(label="電池", value="BATTERIES"),
            discord.SelectOption(label="顯示屏", value="DISPLAYS"),
            discord.SelectOption(label="智能手機", value="SMP"),
            discord.SelectOption(label="平板電腦", value="TAB"),
            discord.SelectOption(label="筆記型電腦", value="LAPTOP"),
            discord.SelectOption(label="顯示器", value="MONITORS"),
            discord.SelectOption(label="電視機", value="TELEVISION"),
            discord.SelectOption(label="機器人", value="ROBOTS"),
            discord.SelectOption(label="精密電子元件", value="HGEC"),
            discord.SelectOption(label="無人機", value="QUADCOPTER"),
        ]
    )
    async def selects(self, i:discord.Interaction,select_item : discord.ui.Select):#下拉選擇完成之後的邏輯
        if(select_item.values == ['PROCESSORS']):
          id=20
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['Electronic']):
          id=21
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['BATTERIES']):
          id=22
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['DISPLAYS']):
          id=23
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['SMP']):
          id=24
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['TAB']):
          id=25
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['LAPTOP']):
          id=26
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['MONITORS']):
          id=27
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['TELEVISION']):
          id=28
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['ROBOTS']):
          id=114
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['HGEC']):
          id=79
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['QUADCOPTER']):
          id=98
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)



class AutomotiveCol(discord.ui.View):#view是選擇的那個框
    answer1=None#這是可以傳到主程序的變量（變數）
    @discord.ui.select(
                placeholder="請選擇物資！",#這是下拉框的提示内容
                options=[
                    discord.SelectOption(label="推土機", value="DULLDOZER"),#這是選項中的一個選項
                    discord.SelectOption(label="車載電腦", value="OBC"),
                    discord.SelectOption(label="電動馬達", value="EM"),
                    discord.SelectOption(label="豪華車内飾", value="LI"),
                    discord.SelectOption(label="基本内飾", value="BI"),
                    discord.SelectOption(label="車身", value="CB"),
                    discord.SelectOption(label="内燃機", value="CE"),
                    discord.SelectOption(label="經濟電動車", value="EEC"),
                    discord.SelectOption(label="豪華電動車", value="LEC"),
                    discord.SelectOption(label="經濟燃油車", value="EC"),
                    discord.SelectOption(label="豪華燃油車", value="LC"),
                    discord.SelectOption(label="卡車", value="TRUCK"),
                ]
            )
    async def selects(self, i:discord.Interaction,select_item : discord.ui.Select):#下拉選擇完成之後的邏輯
          if(select_item.values == ['DULLDOZER']):
            id=112
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
          elif(select_item.values == ['OBC']):
            id=47
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
          elif(select_item.values == ['EM']):
            id=48
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
          elif(select_item.values == ['LI']):
            id=49
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
          elif(select_item.values == ['BI']):
            id=50
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
          elif(select_item.values == ['CB']):
            id=51
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
          elif(select_item.values == ['CE']):
            id=52
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
          elif(select_item.values == ['EEC']):
            id=53
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
          elif(select_item.values == ['LEC']):
            id=54
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
          elif(select_item.values == ['EC']):
            id=55
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
          elif(select_item.values == ['LC']):
            id=56
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
          elif(select_item.values == ['TRUCK']):
            id=57
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()

class AerospaceCol(discord.ui.View):#view是選擇的那個框
      answer1=None#這是可以傳到主程序的變量（變數）
      @discord.ui.select(
          placeholder="請選擇物資！",#這是下拉框的提示内容
          options=[
                    discord.SelectOption(label="機身", value="FUSELAGE"),#這是選項中的一個選項
                    discord.SelectOption(label="機翼", value="WING"),
                    discord.SelectOption(label="飛行計算機", value="FC"),
                    discord.SelectOption(label="座艙", value="COCKPIT"),
                    discord.SelectOption(label="姿態控制器", value="AC"),
                    discord.SelectOption(label="燃料儲罐", value="PT"),
                    discord.SelectOption(label="固體燃料助推器", value="SFB"),
                    discord.SelectOption(label="火箭發動機", value="RE"),
                    discord.SelectOption(label="隔熱板", value="HS"),
                    discord.SelectOption(label="離子推進器", value="ID"),
                    discord.SelectOption(label="噴射發動機", value="JE"),
                    discord.SelectOption(label="亞軌道二級火箭", value="SO2S"),
                    discord.SelectOption(label="亞軌道火箭", value="SOR"),
                    discord.SelectOption(label="軌道助推器", value="OB"),
                    discord.SelectOption(label="星際飛船", value="STARSHIP"),
                    discord.SelectOption(label="BFR", value="BFR"),
                    discord.SelectOption(label="噴射客機", value="JJ"),
                    discord.SelectOption(label="豪華飛機", value="LJ"),
                    discord.SelectOption(label="單引擎飛機", value="SEP"),
                    discord.SelectOption(label="人造衛星", value="SAT"),
                ]
            )
      async def selects(self, i:discord.Interaction,select_item : discord.ui.Select):#下拉選擇完成之後的邏輯
          if(select_item.values == ['FUSELAGE']):
              response=requests.get('https://www.simcompanies.com/api/v3/market/0/133/')#從api中拉入價格數據


class ResourcesCol(discord.ui.View):#view是選擇的那個框
    answer1=None#這是可以傳到主程序的變量（變數）
    @discord.ui.select(
        placeholder="請選擇物資！",#這是下拉框的提示内容
        options=[
            discord.SelectOption(label="水", value="WATER"),#這是選項中的一個選項
            discord.SelectOption(label="運輸單位", value="TRANSPORT"),
            discord.SelectOption(label="塑料", value="PLASTIC"),
            discord.SelectOption(label="礦物", value="MINE"),
            discord.SelectOption(label="鋁土礦", value="BAUX"),
            discord.SelectOption(label="矽材", value="SILI"),
            discord.SelectOption(label="化合物", value="CHEMI"),
            discord.SelectOption(label="鋁材", value="ALUMINIUM"),
            discord.SelectOption(label="鐵礦石", value="IRON"),
            discord.SelectOption(label="鋼材", value="STEEL"),
            discord.SelectOption(label="沙子", value="SAND"),
            discord.SelectOption(label="玻璃", value="GLASS"),
            discord.SelectOption(label="金礦石", value="GOLDO"),
            discord.SelectOption(label="金條", value="GOLDB"),
            discord.SelectOption(label="碳纖維", value="CF"),
            discord.SelectOption(label="碳纖複合材", value="CC"),
        ]
    )
    async def selects(self, i:discord.Interaction,select_item : discord.ui.Select):#下拉選擇完成之後的邏輯
        if(select_item.values == ['WATER']):
          id=2
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['TRANSPORT']):
          id=13
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['PLASTIC']):
          id=19
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['MINE']):
          id=14
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['BAUX']):
          id=15
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['SILI']):
          id=16
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['CHEMI']):
          id=17
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['ALUMINIUM']):
          id=18
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['IRON']):
          id=42
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['STEEL']):
          id=43
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['SAND']):
          id=44
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['GLASS']):
          id=45
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['GOLDO']):
          id=68
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['GOLDB']):
          id=69
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['CF']):
          id=75
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)
        elif(select_item.values == ['CC']):
          id=76
          view = functionmenu(ids=id)
          await i.response.send_message(view=view,ephemeral=True)


class ResearchCol(discord.ui.View):#view是選擇的那個框
    answer1=None#這是可以傳到主程序的變量（變數）
    @discord.ui.select(
        placeholder="請選擇物資！",#這是下拉框的提示内容
        options=[
            discord.SelectOption(label="作物研究", value="PR"),#這是選項中的一個選項
            discord.SelectOption(label="能源研究", value="ER1"),
            discord.SelectOption(label="采礦研究", value="MR1"),
            discord.SelectOption(label="畜牧研究", value="BR"),
            discord.SelectOption(label="化學研究", value="CR"),
            discord.SelectOption(label="時裝研究", value="FR"),
            discord.SelectOption(label="材料研究", value="MR2"),
            discord.SelectOption(label="食譜", value="RECIPT"),
            discord.SelectOption(label="電器研究", value="ER2"),
            discord.SelectOption(label="軟件", value="SW"),
            discord.SelectOption(label="汽車研究", value="VR"),
            discord.SelectOption(label="航空航天研究", value="AR2"),
        ]
    )
    async def selects(self, i:discord.Interaction,select_item : discord.ui.Select):#下拉選擇完成之後的邏輯
          if(select_item.values == ['PR']):
            id=29
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
          elif(select_item.values == ['ER1']):
            id=30
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
          elif(select_item.values == ['MR1']):
            id=31
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
          elif(select_item.values == ['BR']):
            id=32
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
          elif(select_item.values == ['CR']):
            id=34
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
          elif(select_item.values == ['FR']):
            id=59
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
          elif(select_item.values == ['MR2']):
            id=113
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
          elif(select_item.values == ['RECIPT']):
            id=145
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
          elif(select_item.values == ['ER2']):
            id=32
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
          elif(select_item.values == ['SW']):
            id=35
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
          elif(select_item.values == ['VR']):
            id=58
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
          elif(select_item.values == ['AR2']):
            id=100
            view = functionmenu(ids=id)
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()

# 載入 .esv 文件中的變量

load_dotenv()
TOKEN = userdata.get('DISCORD_TOKEN')
    # 初始化機器人
intents = discord.Intents.default()
client= commands.Bot(command_prefix="!", intents=intents)
clients = discord.Client(intents=intents)




@client.event
async def on_ready():
    print(f"{Fore.YELLOW}登入為 {client.user.name}")
    print(f"{Fore.YELLOW}Bot ID: {client.user.id}")
    print(f"{Fore.YELLOW}Discord Version: {discord.__version__}")
    print(f"{Fore.YELLOW}Python版本: {platform.python_version()}")
    synced = await client.tree.sync()
    print(f"{Fore.YELLOW}Slash CMDs 同步: {len(synced)} 命令")

    # 定义開機命令
#@client.tree.command(name="關機", description="玩笑")
#async def startup(interaction: discord.Interaction):
    #time.sleep(5)
    #await interaction.response.send_message(content="哈哈 關不掉我！")

    # 定义晚安命令
#@client.tree.command(name="晚安", description="掰掰")
#async def goodnights(interaction: discord.Interaction):
    #await interaction.response.send_message(content="晚安")

#@client.tree.command(name="喵", description="喵喵喵")
#async def meow(interaction: discord.Interaction):
    #await interaction.response.send_message(content="我們一起學貓叫\n一起喵喵喵喵喵\n在你面前撒個嬌\n哎呦喵喵喵喵喵")

@client.tree.command(name="chatgpt", description="你好")
async def meow(interaction: discord.Interaction,輸入框:str):
    await interaction.response.send_message(content="你好！请问有什么可以帮助您的吗？")
    a=輸入框
    rsp=chatgpt(a)
    await interaction.followup.send(rsp)

#@client.tree.command(name="贅沢な匙", description="喵喵喵")
#async def meow(interaction: discord.Interaction):
    #await interaction.response.send_message(content="クドクド シテルコトバッカリ \nサッパリトシタイ アジワウミライ\n痛んだ小競り合いは 伸び切った舌戦なんか\n飽きて匙を投げる そりゃ遠くに\n巡り巡ってあなたのために掬う\nあぁ スプーンにでもなれたらいいなぁ\n絵に描いたご馳走じゃないのに\nフォンから作るソースじゃないのに\nちょっとばっかなぜでしょう 垂涎ものね\n色鮮やかなサラダボウルに\n好き嫌いも笑って試して\n案外好きなってるんじゃん\n鈍色の天気の日には\n厚い雲を裂いていくような\n風を見てみたい 魔法を見てみたい\n思いつくだけのレシピを眺めて\n振る舞おうぜ何回だって できたての料理を\n満開の笑みが見られたのなら\n創造の手間もどうだっていい\n知らない巡り合いは とんでもない未来\n分け合えると知るんだ不揃いな皿でも\n運命小さじ一杯 朝まで目一杯\n話そう大小ご希望のプランを\nそうやって贅沢な匙を探していこう\nぬくもりもまどろみも 今日の催促で飛んでく\n準備するから連れてって欲しいのさ\n朝日が良く見えるあの丘に\nレジャーシートの用意も\nブランケットの装備も\n全てぱっぱと集めて揃ったよ\n思い付きのキャンピングへ\n誰でも巻き込み招待\nおもいっきり期待が空ぶったとしても \n理不尽ばっか襲ってきたって言いたくなっても \nどうやったってダメな日もあるけど \nその失敗もスパイスなんだろう\n初めての料理がどんな苦くても  \n誇らしく思うんだ傷テープ貼った手で\nやりきった精一杯 後悔しない失敗\n明日にはそう思えるのかな\nマダマダ シラナイコトバッカリ \nユックリトイコウ マンキツシタイ\nタンジュンニ キタイスル コウキシン\nタップリト ミタスヨウ\n隣に居たい ささやかな気持きもち秘めて\n少(すこ)し怯えている不安な夜は\n弱い心照らしだすような\n星を見ていたい 魔法を見てみたい\n思いつくだけのレシピを眺めて \n振る舞おうぜ何回だって できたての料理を\n満開の笑みが見られたのなら\n創造の手間もどうだっていい \n清濁混ぜ和えたとんでもない世界 \n食べ尽くしていくんだ 酸いも甘いも全部\n熱いままにいっぱい 大好きをいっぱい \n詰めよう大層ご機嫌なメニューに\n運命が小さじ一杯 朝まで目一 \n話そう大小ご希望のプランを \nそうやって贅沢な匙を探していこう")


    # 定义计算命令
@client.tree.command(name="單價利潤", description="a=請輸入你需要販賣的數量, b=販賣價格, c=成本(不含運輸單位), d=運輸單位單價")
@app_commands.describe(a="請輸入你需要販賣的數量", b="販賣價格", c="成本(不含運輸單位)", d="運輸單位單價")
async def calculate(interaction: discord.Interaction, a: int, b: float ,c: float ,d: float):
    result = (a*b-(c+a*d))/a
    await interaction.response.send_message(content=f"單價利潤的結果: {result}")

@client.tree.command(name="交易廣告", description="喵鯊叫你去打廣告了")
@app_commands.describe(a="販賣人的名稱", b="販賣的商品", c="販賣的數量", d="販賣價格",e="品質（Q要大寫）")
async def calculate(interaction: discord.Interaction, a: str, b: str ,c: int ,d: float,e:str):
          connect= sqlite3.connect('/content/drive/MyDrive/111.db')
          cursor = connect.cursor()
          cursor.execute("INSERT INTO memberdatas VALUES (?,?,?,?,?,False)", (a,b,d,e,c))
          connect.commit()
          connect.close()

          await interaction.response.send_message(content=f"啾咪，喵鯊已經收到了您的請求！喵鯊會努力為您尋找買家的哦！")
@client.tree.command(name="交易廣告查詢", description="喵鯊正在找靠譜的合夥人")
#@app_commands.describe(a="販賣人的名稱", b="販賣的商品", c="販賣的數量", d="販賣價格",e="品質（Q要大寫）")
async def calculate(interaction: discord.Interaction,name:str,product:str):#, a: str, b: str ,c: int ,d: float,e:str
          connect= sqlite3.connect('/content/drive/MyDrive/111.db')
          cursor = connect.cursor()
          ids=name
          #product='電力'
          table_data = cursor.execute("SELECT * FROM memberdatas WHERE id=? AND product=? AND BOOLfinish!=1;",(ids,product))
          num=0
          result = cursor.fetchall()
          print(print(f"一共有{len(result)}條記錄") )
          quan=''
          # 獲取查詢結果
          quan+=str(f"查詢到{len(result)}條記錄：\n")
          for num in range(len(result)):
            id=result[num][0]
            pro=result[num][1]
            pri=result[num][2]
            qua=result[num][3]
            qut=result[num][4]
            quan+=str(f"{num}.{id}出售了{qut}件{pro}，品質為：{qua}，價格為：{pri}\n")
            quan+='\n'

          await interaction.response.send_message(content=quan)
          connect.close()

@client.tree.command(name="利潤", description="a=請輸入你需要販賣的數量, b=販賣價格, c=成本(不含運輸單位), d=運輸單位單價")
@app_commands.describe(a="請輸入你需要販賣的數量", b="販賣價格", c="成本(不含運輸單位)", d="運輸單位單價")
#import discord
#from dicsord .ext import commands
#import csv

#intents=discord.Intents.default()
#client=
#commands.Bot(command_prefix="!",intents=intents)

async def calculate(interaction: discord.Interaction, a: int, b: float ,c: float ,d: float):
    result = a*b-(c+a*d)
    await interaction.response.send_message(content=f"利潤的結果: {result}")




@client.tree.command(name="資料庫", description="存取 SimCompany 資料庫")
@app_commands.choices(
    產品=[
            app_commands.Choice(name="農業產品", value="Agriculture"),#dA
            app_commands.Choice(name="食品加工業產品", value="Food"),#dB
            app_commands.Choice(name="建築產品", value="Construction"),#dC
            app_commands.Choice(name="時裝業產品", value="Fashion"),#dD
            app_commands.Choice(name="能源行業產品", value="Energy"),#dE
            app_commands.Choice(name="電子產品製造業產品", value="Electronics"),#dF
            app_commands.Choice(name="汽車製造業產品", value="Automotive"),#dG
            app_commands.Choice(name="航空航天製造業產品", value="Aerospace"),#dH
            app_commands.Choice(name="原料加工業產品", value="Resources"),#dI
            app_commands.Choice(name="科研行業產品", value="Research"),#dJ
            ],

    )
async def rps(i: discord.Interaction, 產品: app_commands.Choice[str]):#品質:app_commands.Choice[str]
            await i.response.send_message(content=f"正在檢查身份",ephemeral=True)
            rulescount=len(i.user.roles)
            for num in range(rulescount):
              print(i.user.roles[num])
              if(str(i.user.roles[num])=="會員"):
                print(i.user.roles[num])
                break
              else:
                if(num==int(rulescount)-1):
                  await asyncio.sleep(5)
                  await  i.followup.send(content=f"你沒有權限！",ephemeral=True)#,\n
                  return 0
                else:
                  continue

            if (產品.value == 'Agriculture'):

                table=formsa(dA)
                await asyncio.sleep(10)
                await i.followup.send('```' + str(table) + '```',ephemeral=True)
                i.message.delete()
                #await i.followup.send(content=dA.head(60))

                #打印表格
                #await i.response.send_message(content=dA.head(60))
                #await i.response.send_message(table_content)
            elif (產品.value == 'Food'):
                table=formsa(dB)
                await asyncio.sleep(10)
                await i.response.send_message('```' + str(table) + '```',ephemeral=True)
                #await i.response.send_message(content=dB.head(60))
            elif (產品.value == 'Construction'):
                table=formsa(dC)
                await i.followup.send('```' + str(table) + '```')
                #await i.followup.send(content=dC.head(60))
            elif (產品.value == 'Fashion'):
                table=formsa(dD)
                await i.followup.send('```' + str(table) + '```')
                #await i.followup.send(content=dD.head(60))
            elif (產品.value == 'Energy'):
                table=formsa(dE)
                await i.followup.send('```' + str(table) + '```')
                #await i.followup.send(content=dE.head(60))
            elif (產品.value == 'Electronics'):
                table=formsa(dF)
                await i.followup.send('```' + str(table) + '```')
                #await i.followup.send(content=dF.head(60))
            elif (產品.value == 'Automotive'):
                table=formsa(dG)
                await i.followup.send('```' + str(table) + '```')
                #await i.followup.send(content=dG.head(60))
            elif (產品.value == 'Aerospace'):
                table=formsa(dH)
                await i.followup.send('```' + str(table) + '```')
                #await i.followup.send(content=dH.head(60))
            elif (產品.value == 'Resources'):
                table=formsa(dI)
                await i.followup.send('```' + str(table) + '```')
                #await i.followup.send(content=dI.head(60))
            elif (產品.value == 'Research'):
                table=formsa(dJ)
                await i.followup.send('```' + str(table) + '```')
                #await i.followup.send(content=dJ.head(60))
            else:
                counter = '無'
        #await i.response.send_message(content=f"{counter}")

@client.tree.command(name="test", description="存取 SimCompany 資料庫")
async def rps(i: discord.Interaction,):
            game = discord.Game("喵鯊醬大戰Sim Companies大樓佬")
            await client.change_presence(status=discord.Status.idle, activity=game)


@client.tree.command(name="供應", description="存取 SimCompany 資料庫")
@app_commands.choices(
        產品=[
            app_commands.Choice(name="農業產品", value="Agriculture"),
            app_commands.Choice(name="食品加工業產品", value="Food"),
            app_commands.Choice(name="建築產品", value="Construction"),
            app_commands.Choice(name="時裝業產品", value="Fashion"),
            app_commands.Choice(name="能源行業產品", value="Energy"),
            app_commands.Choice(name="電子產品製造業產品", value="Electronics"),
            app_commands.Choice(name="汽車製造業產品", value="Automotive"),
            app_commands.Choice(name="航空航天製造業產品", value="Aerospace"),
            app_commands.Choice(name="原料加工業產品", value="Resources"),
            app_commands.Choice(name="科研行業產品", value="Research"),
            ],

    )
async def rps(i: discord.Interaction, 產品: app_commands.Choice[str]):#,品質:app_commands.Choice[str]
        times2=datetime.now()
        global zhixingcishu
        print(f"{times2}：供應功能執行了{zhixingcishu}次")
        zhixingcishu=zhixingcishu+1
        if (產品.value == 'Agriculture'):
            view = AgricultureCol()
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
            #results = {
            #    "a1": view.answer1,
            #}
            #await i.response.send_message(f"{results}")

        elif (產品.value == 'Food'):
            view = FoodCol()
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
            #results = {
            #    "a1": view.answer1,
            #}
            #await i.response.send_message(f"{results}")
        elif (產品.value == 'Construction'):
            view = ConstructionCol()
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
        elif (產品.value == 'Fashion'):
            view = FashionCol()
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
        elif (產品.value == 'Energy'):
            view = EnergyCol()
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
        elif (產品.value == 'Electronics'):
            view = ElectronicsCol()
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
        elif (產品.value == 'Automotive'):
            view = AutomotiveCol()
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
        elif (產品.value == 'Aerospace'):
            view = AerospaceCol()
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
        elif (產品.value == 'Resources'):
            view = ResourcesCol()
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
        elif (產品.value == 'Research'):
            view = ResearchCol()
            await i.response.send_message(view=view,ephemeral=True)
            await view.wait()
        else:
            counter = '無'

    # 启动机器人

client.run(TOKEN)





# 定義資料庫命令

    # rest of your command
#async def database(interaction: discord.Interaction):
    # 模擬數據
    #data = [
        #["產品","類別","數量"]
       # ["產品A","類別1","10"]
       # ["產品B","類別2","20"]
       # ["產品C","類別3","30"] ]

      #先發送一條初始訊息
    #await interaction.response.send_message(content="資料庫內容:")

      # 發送後續訊息
   # for datas in data[1:]:
     #   prd=datas[0]
    #    qua=datas[2]
 #await interaction.followup.(content=f"{prd,qua}")
# Out:
# WARNING:discord.client:PyNaCl is not installed, voice will NOT be supported
# 2024-09-27 06:39:36 WARNING  discord.ext.commands.bot Privileged message content intent is missing, commands may not work as expected.
# WARNING:discord.ext.commands.bot:Privileged message content intent is missing, commands may not work as expected.
# 2024-09-27 06:39:36 INFO     discord.client logging in using static token
# INFO:discord.client:logging in using static token
# 2024-09-27 06:39:37 INFO     discord.gateway Shard ID None has connected to Gateway (Session ID: 6921af4dc36285bc9fdc2f32d4261d71).
# INFO:discord.gateway:Shard ID None has connected to Gateway (Session ID: 6921af4dc36285bc9fdc2f32d4261d71).
# 登入為 TWSimCommerce
# Bot ID: 1247479234432077869
# Discord Version: 2.4.0
# Python版本: 3.10.12
# Slash CMDs 同步: 8 命令

# %% [markdown]
# function ClickConnect(){
#   colab.config
#   console.log("Connnect Clicked - Start");
#   document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click();
#   console.log("Connnect Clicked - End");
# };
# setInterval(ClickConnect, 60000) [链接文字](https://)

# %% [markdown]
# 以下為測試區

# %%
import sqlite3

connect= sqlite3.connect('/content/111.db')
cursor = connect.cursor()
print("The 'STUDENT' Table Data:")
ids='wong.global'
product='電力'
table_data = cursor.execute("SELECT * FROM memberdatas WHERE id=? AND BOOLfinish!=1;", (ids,))
for row in table_data:
  print(row)

# 使用參數化的方式插入數據
#cursor.execute("INSERT INTO STUDENT VALUES (?)", (ids,))product
# Out:
# The 'STUDENT' Table Data:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-4-0c16bb873012> in <cell line: 8>()
#       6 ids='wong.global'
#       7 product='電力'
# ----> 8 table_data = cursor.execute("SELECT * FROM memberdatas WHERE id=? AND BOOLfinish!=1;", (ids,))
#       9 for row in table_data:
#      10   print(row)
#
# OperationalError: no such table: memberdatas

# %%
import sqlite3

connect= sqlite3.connect('/content/111.db')
cursor = connect.cursor()
print("The 'STUDENT' Table Data:")
ids='wong.global'
product='電力'
num=0
sql_query = "SELECT * FROM memberdatas WHERE id=? AND BOOLfinish!=1 LIMIT 1 OFFSET 1"
table_data = cursor.execute("SELECT * FROM memberdatas WHERE id=? AND BOOLfinish!=1;", (ids,))
result = cursor.fetchall()
print(len(result))
table_data2 = cursor.execute("SELECT * FROM memberdatas WHERE id=? AND BOOLfinish!=1;", (ids,))

# 獲取查詢結果

print("哈哈")
print(result[0])


# 使用參數化的方式插入數據
#cursor.execute("INSERT INTO STUDENT VALUES (?)", (ids,))product
# Out:
# The 'STUDENT' Table Data:
# 哈哈
# [('wong.global', '電力', 0.246, 'Q1', 1000, 0)]

# %%
import sqlite3

connect= sqlite3.connect('/content/111.db')
cursor = connect.cursor()
print("The 'STUDENT' Table Data:")
ids='wong.global'
product='電力'
table_data = cursor.execute("SELECT * FROM memberdatas WHERE BOOLfinish!=1;")
num=0
result = cursor.fetchall()
print(len(result))
quan=''
# 獲取查詢結果
quan+=str(f"查詢到{len(result)}條記錄：\n")
for num in range(len(result)):
  id=result[num][0]
  pro=result[num][1]
  pri=result[num][2]
  qua=result[num][3]
  qut=result[num][4]
  quan+=str(f"{num}.{id}出售了{qut}件{pro}，品質為：{qua}，價格為：{pri}\n")
  quan+='\n'

print(quan)
connect.close()
# 使用參數化的方式插入數據
#cursor.execute("INSERT INTO STUDENT VALUES (?)", (ids,))product
# Out:
# The 'STUDENT' Table Data:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-3-d9af3c89f4be> in <cell line: 8>()
#       6 ids='wong.global'
#       7 product='電力'
# ----> 8 table_data = cursor.execute("SELECT * FROM memberdatas WHERE BOOLfinish!=1;")
#       9 num=0
#      10 result = cursor.fetchall()
#
# OperationalError: no such table: memberdatas

# %%
import discord
from discord import app_commands
from discord.ext import commands
from typing import List
from google.colab import userdata
import asyncio
import nest_asyncio
nest_asyncio.apply()

# 創建一個子類，繼承自 commands.Bot
load_dotenv()
TOKEN = userdata.get('DISCORD_TOKEN')
    # 初始化機器人
intents = discord.Intents.default()
client= commands.Bot(command_prefix="!", intents=intents)
clients = discord.Client(intents=intents)

# 這裡定義了一個全局變量，用於存儲產品和相關平直的對應關係
product_to_flatness = {
    '產品A': ['平直1', '平直2'],
    '產品B': ['平直3', '平直4'],
    '產品C': ['平直5', '平直6']
}

bot = MyBot()

@client.tree.command(name="test", description="存取 SimCompany 資料庫")
@app_commands.describe(product='選擇產品')
async def choose(interaction: discord.Interaction, product: str):
    # 這裡可以處理產品選擇
    await interaction.response.send_message(f'您選擇了產品: {product}')

@choose.autocomplete('product')
async def product_autocomplete(
    interaction: discord.Interaction,
    current: str,
) -> List[app_commands.Choice[str]]:
    # 根據用戶的當前輸入動態生成產品選項列表
    return [
        app_commands.Choice(name=product, value=product)
        for product in product_to_flatness.keys() if current.lower() in product.lower()
    ]

@bot.tree.command()
@app_commands.describe(product='選擇產品', flatness='選擇平直')
async def choose_flatness(interaction: discord.Interaction, product: str, flatness: str):
    # 這裡可以處理平直選擇
    await interaction.response.send_message(f'您選擇了產品: {product} 和平直: {flatness}')

@choose_flatness.autocomplete('flatness')
async def flatness_autocomplete(
    interaction: discord.Interaction,
    current: str,
) -> List[app_commands.Choice[str]]:
    # 從 interaction 中提取已選擇的產品
    product = interaction.data['options'][0]['value']
    flatness_options = product_to_flatness.get(product, [])
    return [
        app_commands.Choice(name=flat, value=flat)
        for flat in flatness_options if current.lower() in flat.lower()
    ]

# 運行機器人
your_token_here=userdata.get('DISCORD_TOKEN')
client.run(your_token_here)
